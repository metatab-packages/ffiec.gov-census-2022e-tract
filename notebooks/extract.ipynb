# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
# NOTE! Opening built package, not source package, to get access to the previously built ffiec_distressed
# dataset
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Distressed Housing Tracts 2013-2021
# `ffiec.gov-census-tract-1.6.4` Last Update: 2022-10-30T15:35:53
#
# _An extract of a subset of columns from the FFIEC Census Flat File, including flags that indicate a tract is distressed._
#
#
# This dataset extracts the columns for distressed tracts from the FFIEC compilation of census data, for use in their FFIEC Census Windows Application. It includes only 25 columns, the first 17 columns of the file, which have geographic identifiers, median income, and three population totals. The reamaining 8 columns hold flags to indicate if a tract is distressed.
#
# * 1205	Identifies Income Level Indicator
# * 1206	Meets current year's poverty CRA distressed criterion?
# * 1207	Meets current year's unemployment CRA distressed criterion?
# * 1208	Meets current year's population CRA distressed criterion?
# * 1209	Meets current year's remote rural (low density) CRA underserved criterion?
# ...

# %%
df = pkg.resource('ffiec_distressed').dataframe()
df.head()
# Out:
#                 geoid  year  msa_md_code  state  county  tract  \
# 0  14000US01001020100  2013        33860      1       1  20100
# 1  14000US01001020200  2013        33860      1       1  20200
# 2  14000US01001020300  2013        33860      1       1  20300
# 3  14000US01001020400  2013        33860      1       1  20400
# 4  14000US01001020500  2013        33860      1       1  20500
#
#    principal_city_flag small_county_flag split_tract_flag demo_flag  ...  \
# 0                 <NA>                 T                N         D  ...
# 1                 <NA>                 T                N         D  ...
# 2                 <NA>                 T                N         D  ...
# 3                 <NA>                 T                N         D  ...
# 4                 <NA>                 T                N         D  ...
#
#   nonwhite  minority_percent  income_level  poverty_distressed  \
# 0      311                16             4
# ...

# %%
cols = ['geoid', 'year', 'msa_md_code', 'urban_rural_flag', 'msa_family_income',
       'msa_household_income', 'tract_household_income',
       'tract_family_income_pct', 'ffiec_median_income', 'population',
       'families', 'households', 'female', 'male', 'nonwhite',
       'minority_percent', 'income_level', 'poverty_distressed',
       'unemployment_distressed', 'population_distressed', 'rural_underserved',
       'last_year_distressed', 'last_year_underserved',
       'current_prior_distressed']

df = df[cols]
df.head().T
# Out:
#                                            0                   1  \
# geoid                     14000US01001020100  14000US01001020200
# year                                    2013                2013
# msa_md_code                            33860               33860
# urban_rural_flag                           M                   U
# msa_family_income                      58143               58143
# msa_household_income                   46404               46404
# tract_household_income                 70222               41091
# tract_family_income_pct               132.09                84.6
# ffiec_median_income                    61500               61500
# population                              1912                2170
# families                                 545                 456
# households                               696                 730
# female                                   965                1157
# ...

# %%
df[df.year==2022].unemployment_distressed.value_counts()
# Out:
# 0       31526
# 9        1085
# 8        1075
# 10        996
# 7         993
#         ...
# 905         1
# 950         1
# 948         1
# 1257        1
# 939         1
# Name: unemployment_distressed, Length: 1145, dtype: int64

# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Distressed Housing Tracts, 2022 on
# `ffiec.gov-census-2022e-tract-1.1.1` Last Update: 2022-10-31T20:01:12
#
# _An extract of a subset of columns from the FFIEC Census Flat File, including flags that indicate a tract is distressed._
#
#
# This dataset extracts the columns for distressed tracts from the FFIEC compilation of census data, for use in their FFIEC Census Windows Application. It includes only 25 columns, the first 17 columns of the file, which have geographic identifiers, median income, and three population totals. The reamaining 8 columns hold flags to indicate if a tract is distressed.
#
# * 1205	Identifies Income Level Indicator
# * 1206	Meets current year's poverty CRA distressed criterion?
# * 1207	Meets current year's unemployment CRA distressed criterion?
# * 1208	Meets current year's population CRA distressed criterion?
# * 1209	Meets current year's remote rural (low density) CRA underserved criterion?
# ...

# %%
# 2022 has a lot of new tracts, about 11,400 more
g22 = set(df[df.year == 2022].geoid)
g21 = set(df[df.year == 2021].geoid)

print(len(g22), len(g21))

new_tracts = list(g22 - g21)

df[df.geoid.isin(new_tracts)].sample(20)
# Out:
# 87275 0
#                     geoid  year  msa_md_code  state  county   tract  \
# 83555  14000US53063013003  2022        44060     53      63   13003
# 81936  14000US51810045433  2022        47260     51     810   45433
# 4666   14000US06001450752  2022        36084      6       1  450752
# 23943  14000US13227050500  2022        12060     13     227   50500
# 19604  14000US12095012202  2022        36740     12      95   12202
# 78707  14000US48491021300  2022        12420     48     491   21300
# 72491  14000US48041002017  2022        17780     48      41    2017
# 38780  14000US26025000900  2022        12980     26      25     900
# 32631  14000US21067003704  2022        30460     21      67    3704
# 41792  14000US27017070300  2022        20260     27      17   70300
# 7414   14000US06037533806  2022        31084      6      37  533806
# 72687  14000US48061014403  2022        15180     48      61   14403
# 43872  14000US28107950400  2022        99999     28     107  950400
# ...

# %%
df = pkg.resource('ffiec_distressed_ss').dataframe()
df.sample(10).head().T
# Out:
#                                        76386               78516  \
# geoid                     14000US48257050701  14000US48479001824
# geoid_tiger                      48257050701         48479001824
# year                                    2022                2022
# msa_md_code                            19124               29700
# urban_rural_flag                           0                   0
# msa_family_income                    88315.0             54078.0
# msa_household_income                 74251.0             50296.0
# tract_household_income               88382.0             80106.0
# tract_family_income_pct               108.72              140.39
# ffiec_median_income                  97400.0             66000.0
# population                            5571.0              4669.0
# families                              1040.0              1104.0
# households                            1304.0              1170.0
# ...

# %%
df.last_year_distressed.value_counts()
# Out:
# 0    87275
# Name: last_year_distressed, dtype: Int64

# %%
df.dtypes
# Out:
# geoid                        object
# geoid_tiger                  object
# year                          Int64
# msa_md_code                   Int64
# urban_rural_flag             object
# msa_family_income           float64
# msa_household_income        float64
# tract_household_income      float64
# tract_family_income_pct     float64
# ffiec_median_income         float64
# population                  float64
# families                    float64
# households                  float64
# female                      float64
# male                        float64
# nonwhite                    float64
# minority_percent            float64
# income_level                float64
# poverty_distressed            Int64
# unemployment_distressed       Int64
# population_distressed         Int64
# rural_underserved             Int64
# last_year_distressed          Int64
# last_year_underserved         Int64
# current_prior_distressed      Int64
# dtype: object

# %%
pkg = mp.open_package('http://library.metatab.org/ffiec.gov-census-2022e-tract-1.1.1.csv')

# Create Dataframes
ffiec_distressed_df = pkg.resource('ffiec_distressed').dataframe()
ffiec_distressed_ss_df = pkg.resource('ffiec_distressed_ss').dataframe()

# %%
ffiec_distressed_ss_df.sample(10).head().T
# Out:
#                                        42067               5567   \
# geoid                     14000US27053000102  14000US06029004305
# geoid_tiger                      27053000102         06029004305
# year                                    2022                2022
# msa_md_code                            33460               12540
# urban_rural_flag                           0                   0
# msa_family_income                   103977.0             61044.0
# msa_household_income                 82887.0             54851.0
# tract_household_income               46333.0             98906.0
# tract_family_income_pct                46.38              162.02
# ffiec_median_income                 117800.0             67900.0
# population                            5178.0              1665.0
# families                               809.0               361.0
# households                            1752.0               361.0
# ...
